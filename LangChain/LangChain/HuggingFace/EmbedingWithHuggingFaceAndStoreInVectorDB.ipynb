# %%
# !pip install langchain_huggingface
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 50.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 47.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 37.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 15.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 88.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
# !pip install sentence_transformers

# %%
HF_TOKEN="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"

# %%
from langchain_huggingface import HuggingFaceEmbeddings
embeddings=HuggingFaceEmbeddings(model_name="all-MiniLm-L6-v2")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# ...

# %%
text="This is attest documents"
## for single string
query_results=embeddings.embed_query(text)
query_results
# Out:
# [-0.08125586062669754,
#  0.08999317139387131,
#  -0.018281089141964912,
#  0.03780292347073555,
#  0.10140864551067352,
#  -0.022057706490159035,
#  -0.012959483079612255,
#  -0.05231655761599541,
#  0.008947237394750118,
#  0.0476062186062336,
#  0.050549063831567764,
#  0.024559520184993744,
#  0.04363558813929558,
#  -0.0088594825938344,
#  -0.08852597326040268,
#  0.008929438889026642,
#  0.012788604944944382,
#  -0.029939457774162292,
#  0.021358536556363106,
#  0.07564576715230942,
#  0.002105590421706438,
#  0.09457655996084213,
#  -0.02279365062713623,
#  0.021674668416380882,
#  0.028654269874095917,
#  -0.013797743245959282,
#  -0.1368517130613327,
#  -0.01416938565671444,
#  0.03212506324052811,
#  -0.049903079867362976,
#  0.07459890842437744,
#  0.07652878761291504,
#  0.02442152239382267,
#  0.06071395054459572,
#  0.0526653528213501,
#  0.011528498493134975,
#  0.0783165916800499,
#  -0.01502835750579834,
#  0.008408068679273129,
#  -0.020016569644212723,
# ...

# %%
len(query_results)
# Out:
# 384

# %%
## For multiple string/a document
doc_results=embeddings.embed_documents([text,"This is not a test document"])
doc_results[0]
# Out:
# [-0.08125586062669754,
#  0.08999313414096832,
#  -0.01828104443848133,
#  0.037802886217832565,
#  0.10140866786241531,
#  -0.02205771394073963,
#  -0.012959464453160763,
#  -0.05231659859418869,
#  0.008947232738137245,
#  0.0476062074303627,
#  0.05054907873272896,
#  0.024559475481510162,
#  0.0436355322599411,
#  -0.008859465830028057,
#  -0.08852595090866089,
#  0.008929463103413582,
#  0.01278864685446024,
#  -0.02993948385119438,
#  0.021358558908104897,
#  0.07564575970172882,
#  0.002105597173795104,
#  0.09457656741142273,
#  -0.022793639451265335,
#  0.021674660965800285,
#  0.0286543108522892,
#  -0.01379778515547514,
#  -0.1368517279624939,
#  -0.014169322326779366,
#  0.032125018537044525,
#  -0.049903105944395065,
#  0.07459890842437744,
#  0.07652878016233444,
#  0.02442152611911297,
#  0.060713909566402435,
#  0.05266536772251129,
#  0.011528493836522102,
#  0.07831661403179169,
#  -0.015028350055217743,
#  0.008408090099692345,
#  -0.020016606897115707,
# ...
