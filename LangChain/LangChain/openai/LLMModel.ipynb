# %%
import os
from dotenv import load_dotenv
load_dotenv()
os.environ["OPEN_API_KEY"]=os.getenv('OPEN_API_KEY')
os.environ["LANGCAHIN_API_KEY"]=os.getenv('LANGCAHIN_API_KEY')
os.environ["LANGCHAIN_TRACING_V2"]="true"
os.environ["LANGCHAIN_PROJECT"]=os.getenv('LANGCHAIN_PROJECT')

# %%
from langchain_openai import ChatOpenAI
OPEN_API_KEY="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"
llm=ChatOpenAI(api_key=OPEN_API_KEY,model="gpt-4o")
print(llm)
# Out:
# client=<openai.resources.chat.completions.completions.Completions object at 0x000002919AC61E40> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x000002919AC74BB0> root_client=<openai.OpenAI object at 0x000002919AC39CF0> root_async_client=<openai.AsyncOpenAI object at 0x000002919AC61EA0> model_name='gpt-4o' model_kwargs={} openai_api_key=SecretStr('**********')

# %%
### Input and get response from LLM

result=llm.invoke("What is Generative AI")
# Out:
# e:\DS_ML_AI_DL_GENAI_practice\LangChain\venv\lib\site-packages\langsmith\client.py:272: LangSmithMissingAPIKeyWarning: API key must be provided when using hosted LangSmith API
#   warnings.warn(
# Failed to multipart ingest runs: langsmith.utils.LangSmithAuthError: Authentication failed for https://api.smith.langchain.com/runs/multipart. HTTPError('401 Client Error: Unauthorized for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Unauthorized"}\n')trace=115f4429-6317-463a-ac06-ac4f9d484ba6,id=115f4429-6317-463a-ac06-ac4f9d484ba6
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithAuthError: Authentication failed for https://api.smith.langchain.com/runs/multipart. HTTPError('401 Client Error: Unauthorized for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Unauthorized"}\n')trace=115f4429-6317-463a-ac06-ac4f9d484ba6,id=115f4429-6317-463a-ac06-ac4f9d484ba6; trace=ed839d11-d8db-43ef-ab96-8e311950ba78,id=ed839d11-d8db-43ef-ab96-8e311950ba78; trace=ed839d11-d8db-43ef-ab96-8e311950ba78,id=9cc796fe-41e1-4d84-a665-fbc6a09c626c; trace=ed839d11-d8db-43ef-ab96-8e311950ba78,id=9cc796fe-41e1-4d84-a665-fbc6a09c626c; trace=ed839d11-d8db-43ef-ab96-8e311950ba78,id=2876b2d2-dbb0-47f8-994d-eae1b55af480
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithAuthError: Authentication failed for https://api.smith.langchain.com/runs/multipart. HTTPError('401 Client Error: Unauthorized for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Unauthorized"}\n')trace=ed839d11-d8db-43ef-ab96-8e311950ba78,id=2876b2d2-dbb0-47f8-994d-eae1b55af480; trace=ed839d11-d8db-43ef-ab96-8e311950ba78,id=ed839d11-d8db-43ef-ab96-8e311950ba78
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithAuthError: Authentication failed for https://api.smith.langchain.com/runs/multipart. HTTPError('401 Client Error: Unauthorized for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Unauthorized"}\n')trace=5dfba019-3ac6-43cd-8808-8c86fd4d66fe,id=5dfba019-3ac6-43cd-8808-8c86fd4d66fe; trace=5dfba019-3ac6-43cd-8808-8c86fd4d66fe,id=0a1c9dae-a1ee-4031-ac2c-75823ce4b637; trace=5dfba019-3ac6-43cd-8808-8c86fd4d66fe,id=0a1c9dae-a1ee-4031-ac2c-75823ce4b637; trace=5dfba019-3ac6-43cd-8808-8c86fd4d66fe,id=e346ad13-a4ab-4595-966a-2d835809c13b
# Failed to send compressed multipart ingest: langsmith.utils.LangSmithAuthError: Authentication failed for https://api.smith.langchain.com/runs/multipart. HTTPError('401 Client Error: Unauthorized for url: https://api.smith.langchain.com/runs/multipart', '{"error":"Unauthorized"}\n')trace=5dfba019-3ac6-43cd-8808-8c86fd4d66fe,id=e346ad13-a4ab-4595-966a-2d835809c13b; trace=5dfba019-3ac6-43cd-8808-8c86fd4d66fe,id=5ec9c3ff-28be-4012-9325-20e2c7f079e9; trace=5dfba019-3ac6-43cd-8808-8c86fd4d66fe,id=5ec9c3ff-28be-4012-9325-20e2c7f079e9; trace=5dfba019-3ac6-43cd-8808-8c86fd4d66fe,id=5dfba019-3ac6-43cd-8808-8c86fd4d66fe

# %%
print(result.content)
# Out:
# Generative AI refers to a category of artificial intelligence techniques designed to produce data or content similar to what it has been trained on. Unlike conventional AI, which typically focuses on classification or prediction tasks, generative AI aims to create new instances modeled after its training examples. Here are key aspects of generative AI:
#
# 1. **Types of Content**: Generative AI can produce a wide range of outputs, including text, images, music, and complex datasets.
#
# 2. **Models**: Some of the most prominent models in generative AI include:
#    - **Generative Adversarial Networks (GANs)**: These involve two neural networks, a generator and a discriminator, which are trained together to produce realistic data.
#    - **Variational Autoencoders (VAEs)**: These models learn to encode input data into a latent space and then decode it back, allowing for the generation of new data points by sampling from the latent space.
#    - **Transformers**: Models like GPT (Generative Pre-trained Transformer) are used for natural language processing tasks, generating coherent text based on prompts.
#
# 3. **Applications**:
#    - **Text Generation**: Language models, such as GPT, can generate human-like text, assist in writing, or create conversational agents.
#    - **Image Creation**: Tools like DALL-E and StyleGAN can generate realistic or artistic images and art.
#    - **Music and Audio Synthesis**: Generative AI can create music, sound effects, and even voices, useful in entertainment and media.
#    - **Design and Creativity**: It can aid in designing products, architecture, or digital characters by generating novel ideas or prototypes.
#
# 4. **Challenges and Considerations**:
#    - **Ethical Use**: Concerns around copyright, misinformation, and the misuse of generated content.
#    - **Bias and Representation**: Models may inadvertently propagate existing biases present in the training data.
#    - **Quality Control**: Ensuring the generated content is safe, accurate, and aligns with user or societal values.
#
# Overall, generative AI holds immense potential across various fields by providing tools for creativity, efficiency, and innovation. However, it also necessitates careful consideration of its ethical and societal impacts.

# %%
## Chat Promt template:
from langchain_core.prompts import ChatPromptTemplate
prompt=ChatPromptTemplate.from_messages(
  [
    ("system","Your are an expert AI engineer.Provide me answers based omn the question"),
    ("user",f"{input}")
    
  ]
)
prompt
# Out:
# ChatPromptTemplate(input_variables=[], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='Your are an expert AI engineer.Provide me answers based omn the question'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='<bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x000002919646AD40>>'), additional_kwargs={})])

# %%
chain=chain=prompt|llm
response=chain.invoke({"input":"Can you tell me LangSmith"})
print(response)
# Out:
# content="It seems like you've pasted some internal IPython object code or output, which typically isn't meaningful outside of a specific programming context. This can happen if you're working within a Jupyter notebook or an IPython environment and trying to access or reference functions through incorrect methods.\n\nIf you intended to ask a specific question about programming, using Jupyter notebooks, or handling kernel errors, please provide more context or clarify your question. I'd be happy to help with any specific inquiry you may have." additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 96, 'prompt_tokens': 53, 'total_tokens': 149, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_55d88aaf2f', 'id': 'chatcmpl-BSjvZI438YjTMV4CNyiNGOJEW9qqx', 'finish_reason': 'stop', 'logprobs': None} id='run-2876b2d2-dbb0-47f8-994d-eae1b55af480-0' usage_metadata={'input_tokens': 53, 'output_tokens': 96, 'total_tokens': 149, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
type(response)
# Out:
# langchain_core.messages.ai.AIMessage

# %%
## Output parser: stroutput: To display msg
from langchain_core.output_parsers import StrOutputParser
output_parser=StrOutputParser()
chain=prompt|llm|output_parser
response=chain.invoke({"input":"Can you tell me LangSmith"})
print(response)
# Out:
# It seems like you've pasted a representation of a bound method from a Python object, likely from an interactive Python shell or Jupyter Notebook environment. This specific method, `raw_input`, is used to take input from the user. However, in modern Python (Python 3 and above), this function is just called `input()`.
#
# If you have a specific question about what you're working on, such as how to use this function in your code, or if you're encountering an error, please provide more details or context so I can assist you better.
